# %%
from iter_summary import *

# %%
wa_wa_list = ['60986197WA.cpp', '59982501WA.cpp', '61566251WA.cpp', '61216233WA.cpp',
 '61451096WA.cpp', '60238769WA.cpp', '60296682WA.cpp', '59169263WA.cpp',
 '59151286WA.cpp', '59149424WA.cpp', '61305445WA.cpp', '59175610WA.cpp',
 '59371826WA.cpp', '59196797WA.cpp', '59164555WA.cpp', '59165140WA.cpp',
 '59194619WA.cpp', '59694677WA.cpp', '59153879WA.cpp', '61015256WA.cpp',
 '59155851WA.cpp', '59151742WA.cpp', '59260062WA.cpp', '60069869WA.cpp',
 '59259042WA.cpp', '60429712WA.cpp', '59168996WA.cpp', '59338624WA.cpp',
 '59321711WA.cpp', '59174853WA.cpp', '59210235WA.cpp', '59199181WA.cpp',
 '60768532WA.cpp', '59160082WA.cpp', '59202593WA.cpp', '59154860WA.cpp',
 '59152571WA.cpp', '59234119WA.cpp', '59173674WA.cpp', '59175504WA.cpp',
 '61528747WA.cpp', '59531550WA.cpp', '59601700WA.cpp', '59222384WA.cpp',
 '59166402WA.cpp', '59253551WA.cpp', '59241185WA.cpp', '59159670WA.cpp',
 '59183568WA.cpp', '59168049WA.cpp', '59152060WA.cpp', '59171731WA.cpp',
 '59145764WA.cpp', '59161691WA.cpp', '59153686WA.cpp', '59182887WA.cpp',
 '59150167WA.cpp', '59476429WA.cpp', '59030137WA.cpp', '60072569WA.cpp',
 '59013040WA.cpp', '59064924WA.cpp', '61118633WA.cpp', '59687548WA.cpp',
 '59010257WA.cpp', '59107027WA.cpp', '59296975WA.cpp', '59211030WA.cpp',
 '61028718WA.cpp', '59687364WA.cpp', '59193002WA.cpp', '61300028WA.cpp',
 '59001799WA.cpp', '59042032WA.cpp', '59050142WA.cpp', '59693562WA.cpp',
 '59002616WA.cpp', '59048358WA.cpp', '59009176WA.cpp', '59027783WA.cpp',
 '59005267WA.cpp', '59054277WA.cpp', '59028479WA.cpp', '59181676WA.cpp',
 '59009305WA.cpp', '60215109WA.cpp', '61540589WA.cpp', '60965718WA.cpp',
 '59002578WA.cpp', '59050998WA.cpp', '59537595WA.cpp', '59255261WA.cpp',
 '59039250WA.cpp', '59011961WA.cpp', '61443999WA.cpp', '59101305WA.cpp',
 '59253994WA.cpp', '59002124WA.cpp', '59140968WA.cpp', '59217987WA.cpp',
 '59022326WA.cpp', '59006026WA.cpp', '59132645WA.cpp', '59003710WA.cpp',
 '59065844WA.cpp', '59002337WA.cpp', '59602107WA.cpp', '59010742WA.cpp',
 '59781647WA.cpp', '59001582WA.cpp', '59002488WA.cpp', '59059046WA.cpp',
 '59011050WA.cpp', '59106554WA.cpp', '59025058WA.cpp', '59049897WA.cpp',
 '59019273WA.cpp', '61370878WA.cpp', '59008136WA.cpp', '59016445WA.cpp',
 '60305726WA.cpp', '59520280WA.cpp', '59011654WA.cpp', '59488862WA.cpp',
 '60779404WA.cpp', '60722630WA.cpp', '60643353WA.cpp', '60563185WA.cpp',
 '60664129WA.cpp', '60547352WA.cpp', '60711834WA.cpp',
 '60561728WA.cpp', '60562820WA.cpp', '60555033WA.cpp',
 '60541895WA.cpp', '60551718WA.cpp', '60542479WA.cpp', '60549306WA.cpp',
 '60590639WA.cpp', '60571764WA.cpp', '60550829WA.cpp', '60580318WA.cpp',
 '60550438WA.cpp', '60724467WA.cpp', '60683962WA.cpp', '60504599WA.cpp',
 '60802237WA.cpp', '60526840WA.cpp', '60674653WA.cpp', '60601742WA.cpp',
 '60501320WA.cpp', '60684965WA.cpp', '60620591WA.cpp', '60723462WA.cpp',
 '60612225WA.cpp', '60662107WA.cpp', '60739629WA.cpp', '60621817WA.cpp',
 '60626810WA.cpp', '60698433WA.cpp', '60623576WA.cpp', '60617785WA.cpp',
 '60613716WA.cpp', '60609973WA.cpp', '60612634WA.cpp', '60613478WA.cpp',
 '60628774WA.cpp', '60644379WA.cpp', '60633434WA.cpp', '60659580WA.cpp',
 '60612716WA.cpp', '60690535WA.cpp', '60615024WA.cpp', '60641931WA.cpp',
 '60609937WA.cpp', '60622500WA.cpp', '60711024WA.cpp', '60661665WA.cpp',
 '60682851WA.cpp', '60678145WA.cpp', '60689623WA.cpp', '60618352WA.cpp',
 '60641993WA.cpp', '60610802WA.cpp', '60641434WA.cpp', '60743602WA.cpp',
 '60610131WA.cpp', '60612888WA.cpp', '60622521WA.cpp', '60665554WA.cpp',
 '60610764WA.cpp', '60747428WA.cpp', '60658062WA.cpp', '60689683WA.cpp',
 '60615569WA.cpp', '60610585WA.cpp', '60611825WA.cpp', '60659916WA.cpp',
 '60609722WA.cpp', '60667631WA.cpp', '60619022WA.cpp', '60907068WA.cpp',
 '60922974WA.cpp', '60833484WA.cpp', '61094793WA.cpp', '60822758WA.cpp',
 '61500143WA.cpp', '61719201WA.cpp', '61510431WA.cpp', '61514213WA.cpp',
 '61525642WA.cpp', '61569354WA.cpp', '61592666WA.cpp', '61488589WA.cpp',
 '61500440WA.cpp', '61481013WA.cpp', '61488511WA.cpp', '61527355WA.cpp',
 '61530045WA.cpp', '61565325WA.cpp', '61717653WA.cpp', '61538918WA.cpp',
 '61510993WA.cpp', '61490113WA.cpp', '61530425WA.cpp', '61528580WA.cpp',
 '61473133WA.cpp', '61497582WA.cpp', '61488186WA.cpp',
 '61507029WA.cpp', '61481627WA.cpp', '61489197WA.cpp', '61504939WA.cpp',
 '61486127WA.cpp', '61507377WA.cpp', '61499333WA.cpp', '61478424WA.cpp',
 '61524998WA.cpp', '61496181WA.cpp', '61484481WA.cpp', '61529969WA.cpp',
 '61548696WA.cpp', '61537430WA.cpp', '61507811WA.cpp', '61516517WA.cpp',
 '61502849WA.cpp', '61515024WA.cpp', '61494721WA.cpp', '61485390WA.cpp',
 '61512727WA.cpp', '61505655WA.cpp', '61531566WA.cpp', '61501937WA.cpp',
 '61491264WA.cpp', '61517359WA.cpp', '61492980WA.cpp', '61488358WA.cpp',
 '61544696WA.cpp', '61487479WA.cpp', '61496858WA.cpp', '61562901WA.cpp',
 '61492785WA.cpp', '61499914WA.cpp', '61492280WA.cpp', '61494404WA.cpp',
 '61496001WA.cpp', '61203540WA.cpp', '61182093WA.cpp', '61169726WA.cpp',
 '61217859WA.cpp', '61191020WA.cpp', '61252363WA.cpp', '61178093WA.cpp',
 '61249749WA.cpp', '61250552WA.cpp', '61188875WA.cpp', '61229926WA.cpp',
 '61222976WA.cpp', '61178872WA.cpp', '61221722WA.cpp', '61199771WA.cpp',
 '61213964WA.cpp', '61219642WA.cpp', '61184618WA.cpp', '61225899WA.cpp',
 '61183102WA.cpp', '61176301WA.cpp', '61187490WA.cpp', '61177870WA.cpp',
 '61251779WA.cpp', '61202544WA.cpp', '61177824WA.cpp', '61403628WA.cpp',
 '61270267WA.cpp', '61215766WA.cpp']

# %%
wa_wa_set = set(wa_wa_list)

# %%
fn_rs = wa_wa_list
rs_rs = []
hst_rsr = []
rt_rs = []
vmc_rs = []

for i, fn in enumerate(fn_s):
    if fn in wa_wa_set:
        rs_rs.append(rs_s[i])
        hst_rsr.append(hst_sr[i])
        rt_rs.append(rt_s[i])
        vmc_rs.append(vmc_s[i])

# %%
#len(rs_rs) == len(fn_rs)

# %%
sum(hst_rsr)
# Out:
# 429742

# %%
sum(rt_rs)
# Out:
# 119122.55703353882

# %%
sum(vmc_rs)
# Out:
# 98006

# %%
for h, r, v in zip(hst_rsr, rt_rs, vmc_rs):
    print(h, ',',r,',',v)
# Out:
# 3231 , 16.023916482925415 , 23
# 298 , 372.27264761924744 , 241
# 93 , 259.67995285987854 , 155
# 175 , 671.2583780288696 , 414
# 31 , 158.47884488105774 , 286
# 67 , 349.87133741378784 , 382
# 77 , 145.18321752548218 , 86
# 5942 , 578.5266332626343 , 350
# 2845 , 311.5957279205322 , 160
# 7200 , 547.5356202125549 , 273
# 759 , 52.74103116989136 , 35
# 2242 , 322.0559763908386 , 180
# 60 , 1095.1294915676117 , 698
# 43 , 44.36438870429993 , 74
# 339 , 119.34959244728088 , 78
# 235 , 139.43713545799255 , 1056
# 36 , 114.92287254333496 , 65
# 111 , 67.45996737480164 , 530
# 3696 , 816.3194987773895 , 538
# 477 , 16.033134937286377 , 33
# 1380 , 895.6513350009918 , 596
# 727 , 102.30350494384766 , 67
# 34 , 4.138873100280762 , 7
# 57 , 42.7735071182251 , 54
# 88 , 39.74917769432068 , 51
# 400 , 10.154801845550537 , 13
# 2748 , 797.4507987499237 , 543
# 97 , 51.13089156150818 , 76
# 63 , 103.9812433719635 , 73
# 687 , 118.26264953613281 , 81
# 219 , 282.2718720436096 , 176
# ...
