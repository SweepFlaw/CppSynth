# %%
import subprocess
import time

import modifyCode

# %%
# input:
#   - code (string)
#   - tmpFilename (string)
#   - cFilename (string) (compiled file name)
#   - inputTestcases (list(bytes))
#   - outputTestcases (list(bytes))
#   - singleTestTimeout (int)
#   - stopFast (bool, optional) (if stopFast true, return immediately when the test fails)
# output:
#   - totalResultCode (0 for success. 1 for testcase error. 2 for compile error. 3 for no testcases)
#   - resultCode for each testcases (list(int)) (0 for success. 1 for W/A. 2 for timeout. 3 for other runtime errors.)
def codeTest(code, tmpFilename, cFilename, inputTestcases, outputTestcases, singleTestTimeout, stopFast=True):
    # exceptional case : no testcases
    if len(inputTestcases) < 1:
        return (3, [])
    
    # put code into file
    with open(tmpFilename, 'w') as file:
        file.write(code)
    # compile
    p = subprocess.run(['g++', tmpFilename, '-o', cFilename], shell=False)
    if p.returncode != 0:
        return (2, [])
    
    # run testcases
    totalResultCode = 0
    resultCodes = []
    for i, o in zip(inputTestcases, outputTestcases):
        try:
            p = subprocess.run([cFilename], input=i, stdout=subprocess.PIPE, stderr=subprocess.PIPE, timeout=singleTestTimeout)
        except subprocess.TimeoutExpired:
            totalResultCode = 1
            resultCodes.append(2)
            if stopFast:
                return totalResultCode, resultCodes
            else:
                continue
        except:
            totalResultCode = 1
            resultCodes.append(3)
            if stopFast:
                return totalResultCode, resultCodes
            else:
                continue
        if o == p.stdout:
            resultCodes.append(0)
        else:
            totalResultCode = 1
            resultCodes.append(1)
            if stopFast:
                return totalResultCode, resultCodes
    return totalResultCode, resultCodes

# %%
# input:
#   - code (list contains the whole code line by line.) (list(string))
#   - vscm (list(dictionary))
#   - tmpFilename (string)
#   - cFilename (string)
#   - modNum (int) (the number of modifications)
#   - inputTestcases (list(bytes))
#   - outputTestcases (list(bytes))
#   - singleTestTimeout (represent timeout seconds.)
#   - totalTimeout (represent timeout seconds. int, optional)  (non-positive value for no-limit)
# output: multiple return values.
#   - modified code String (string) (If it fails to find, return '')
#   - modified codeline Indices, start from 0 (list(int))
#   - selected vscmIndices for successful modification (list(int))
#   - returnStatus(int) (0 for success, 1 for not-found, 2 for timeout, 3 for no testcases)
#   - resultCodes (list(int)) (results for each testcases: following the return value of codeTest.)
#   - elapsed time (int) (seconds)
from itertools import combinations

def findVarErr2(code, vscm, tmpFilename, cFilename, modNum, inputTestcases, outputTestcases, singleTestTimeout, totalTimeout=0):
    if len(inputTestcases) < 1:
        return ('', [], 3, [], 0)
    
    startTime = time.time()
    timeout = startTime + totalTimeout
    validModificationCount = 0
    for mN in range(1, modNum + 1):
        # mT for modification-tuple
        # mL for modification-list
        for mT in combinations(range(len(vscm)), mN):
            # timeout check
            if totalTimeout > 0 and time.time() > timeout:
                return ('', [], [], 2, [], (time.time() - startTime))
        
            # modify Code
            mc, mcis, rs = modifyCode.modCodesFull(code, vscm, mT)
            
            if rs != 0:
                continue
                
            #  test code witih testcases
            trc, rcs = codeTest(mc, tmpFilename, cFilename, inputTestcases, outputTestcases, singleTestTimeout)
            
            # debugging - count the number of iteration
            validModificationCount += 1
            print('===========================================')
            print('validModificationCount   # ' + str(validModificationCount))
            print('TEST RESULTS:')
            print(rcs)
            print('MODIFIED SRC:')
            print(mc)
            print('')
            
            if trc == 0:
                return (mc, mcis, list(mT), 0, rcs, (time.time() - startTime))
    return ('', [], [], 1, [], (time.time() - startTime))

# %% [markdown]
# ## Naive Solver

# %%
### NAIVE SOLUTION
# expected directory layout
# testDir
# - codefname
# - input
#   - 1.txt
#   - 2.txt
#   - ...
# - output
#   - 1.txt
#   - 2.txt
#   - ...

import os
from modifyCode import readVscm, modCodeFull
from makeVscm import genVscm

def naiveSolution2(testDir, codefname, modNumLimit=2, singleTestTimeout=2, testcaseLimit=1000):
    # set filenames
    codeFilename = os.path.join(testDir, codefname)
    vscmFilename = os.path.join(testDir, 'vscm.csv')
    tmpFilename = os.path.join(testDir, 'tmpFile.cpp')
    cFilename = os.path.join(testDir, 'cfile.out')
    inputTCDir = os.path.join(testDir, 'input')
    outputTCDir = os.path.join(testDir, 'output')
    
    # make code string list
    with open(codeFilename, 'r') as codefile:
        code = codefile.readlines()
    
    # make and read vscm
    genVscm(codeFilename, vscmFilename)
    vscm = readVscm(vscmFilename)
    
    # read testcases
    inputTestcases = []
    outputTestcases = []
    for i in range(1, testcaseLimit):
        fn = str(i)
        try:
            with open(os.path.join(inputTCDir, fn), 'rb') as itcf:
                with open(os.path.join(outputTCDir, fn), 'rb') as otcf:
                    inputTestcases.append(itcf.read())
                    outputTestcases.append(otcf.read())
        except IOError:
            break
    
    # run!
    src, linNums, vscmIndices, rs, rcs, etime = findVarErr2(code, vscm, tmpFilename, cFilename, modNumLimit, inputTestcases, outputTestcases, singleTestTimeout)
    print('')
    print('====================================== RESULT')
    print('====================================== RESULT')
    print('====================================== RESULT')
    print('====================================== SRC')
    print(src)
    print('====================================== RS')
    print(rs)
    print('====================================== Result code for each testcases')
    print(rcs)
    print('====================================== VSCM Indices')
    print(vscmIndices)
    print('====================================== modifiedLineNum')
    print(linNums)
    print('====================================== ELAPSED TIME')
    print(etime)
    print('')
    return rs

# %% [markdown]
# ## TEST

# %%
TEST_FLAG=True

# %%
# run naiveSolution
if TEST_FLAG:
    testDir = '/home/ubuntu/workspace/pyws/modifyCpp/naiveSolverTestDir/test1'
    codefname = 'code.cpp'

    naiveSolution2(testDir, codefname)
# Out:
# ===========================================
# validModificationCount   # 1
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> w >> z >> y >> z;
#     cout << w+x << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 2
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> w >> w >> y >> z;
#     cout << w+x << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 3
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> w >> y >> y >> z;
#     cout << w+x << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 4
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> w >> x >> y >> z;
#     cout << w+x << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 5
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> w >> x >> y >> z;
#     cout << w+z << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 6
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> w >> x >> y >> z;
#     cout << w+w << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 7
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> w >> x >> y >> z;
#     cout << w+y << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 8
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> w >> x >> y >> z;
#     cout << w+x << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 9
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> z >> x >> y >> z;
#     cout << w+x << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 10
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> w >> x >> y >> z;
#     cout << w+x << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 11
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> y >> x >> y >> z;
#     cout << w+x << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 12
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> x >> x >> y >> z;
#     cout << w+x << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 13
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> w >> x >> z >> z;
#     cout << w+x << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 14
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> w >> x >> w >> z;
#     cout << w+x << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 15
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> w >> x >> y >> z;
#     cout << w+x << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 16
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> w >> x >> x >> z;
#     cout << w+x << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 17
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> w >> x >> y >> z;
#     cout << z+x << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 18
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> w >> x >> y >> z;
#     cout << w+x << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 19
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> w >> x >> y >> z;
#     cout << y+x << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 20
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> w >> x >> y >> z;
#     cout << x+x << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 21
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> w >> x >> y >> z;
#     cout << w+x << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 22
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> w >> x >> y >> w;
#     cout << w+x << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 23
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> w >> x >> y >> y;
#     cout << w+x << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 24
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> w >> x >> y >> x;
#     cout << w+x << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 25
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> w >> z >> y >> z;
#     cout << w+z << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 26
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> w >> z >> y >> z;
#     cout << w+w << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 27
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> w >> z >> y >> z;
#     cout << w+y << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 28
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> w >> z >> y >> z;
#     cout << w+x << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 29
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> z >> z >> y >> z;
#     cout << w+x << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 30
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> w >> z >> y >> z;
#     cout << w+x << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 31
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> y >> z >> y >> z;
#     cout << w+x << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 32
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> x >> z >> y >> z;
#     cout << w+x << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 33
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> w >> z >> z >> z;
#     cout << w+x << endl;
#     return 0;
# }
# ===========================================
# validModificationCount   # 34
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> w >> z >> w >> z;
#     cout << w+x << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 35
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> w >> z >> y >> z;
#     cout << w+x << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 36
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> w >> z >> x >> z;
#     cout << w+x << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 37
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> w >> z >> y >> z;
#     cout << z+x << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 38
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> w >> z >> y >> z;
#     cout << w+x << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 39
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> w >> z >> y >> z;
#     cout << y+x << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 40
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> w >> z >> y >> z;
#     cout << x+x << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 41
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> w >> z >> y >> z;
#     cout << w+x << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 42
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> w >> z >> y >> w;
#     cout << w+x << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 43
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> w >> z >> y >> y;
#     cout << w+x << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 44
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> w >> z >> y >> x;
#     cout << w+x << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 45
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> w >> w >> y >> z;
#     cout << w+z << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 46
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> w >> w >> y >> z;
#     cout << w+w << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 47
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> w >> w >> y >> z;
#     cout << w+y << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 48
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> w >> w >> y >> z;
#     cout << w+x << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 49
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> z >> w >> y >> z;
#     cout << w+x << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 50
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> w >> w >> y >> z;
#     cout << w+x << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 51
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> y >> w >> y >> z;
#     cout << w+x << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 52
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> x >> w >> y >> z;
#     cout << w+x << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 53
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> w >> w >> z >> z;
#     cout << w+x << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 54
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> w >> w >> w >> z;
#     cout << w+x << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 55
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> w >> w >> y >> z;
#     cout << w+x << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 56
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> w >> w >> x >> z;
#     cout << w+x << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 57
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> w >> w >> y >> z;
#     cout << z+x << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 58
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> w >> w >> y >> z;
#     cout << w+x << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 59
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> w >> w >> y >> z;
#     cout << y+x << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 60
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> w >> w >> y >> z;
#     cout << x+x << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 61
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> w >> w >> y >> z;
#     cout << w+x << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 62
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> w >> w >> y >> w;
#     cout << w+x << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 63
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> w >> w >> y >> y;
#     cout << w+x << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 64
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> w >> w >> y >> x;
#     cout << w+x << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 65
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> w >> y >> y >> z;
#     cout << w+z << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 66
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> w >> y >> y >> z;
#     cout << w+w << endl;
#     return 0;
# }
# ===========================================
# validModificationCount   # 67
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> w >> y >> y >> z;
#     cout << w+y << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 68
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> w >> y >> y >> z;
#     cout << w+x << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 69
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> z >> y >> y >> z;
#     cout << w+x << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 70
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> w >> y >> y >> z;
#     cout << w+x << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 71
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> y >> y >> y >> z;
#     cout << w+x << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 72
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> x >> y >> y >> z;
#     cout << w+x << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 73
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> w >> y >> z >> z;
#     cout << w+x << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 74
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> w >> y >> w >> z;
#     cout << w+x << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 75
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> w >> y >> y >> z;
#     cout << w+x << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 76
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> w >> y >> x >> z;
#     cout << w+x << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 77
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> w >> y >> y >> z;
#     cout << z+x << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 78
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> w >> y >> y >> z;
#     cout << w+x << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 79
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> w >> y >> y >> z;
#     cout << y+x << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 80
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> w >> y >> y >> z;
#     cout << x+x << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 81
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> w >> y >> y >> z;
#     cout << w+x << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 82
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> w >> y >> y >> w;
#     cout << w+x << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 83
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> w >> y >> y >> y;
#     cout << w+x << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 84
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> w >> y >> y >> x;
#     cout << w+x << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 85
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> w >> x >> y >> z;
#     cout << w+z << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 86
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> w >> x >> y >> z;
#     cout << w+w << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 87
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> w >> x >> y >> z;
#     cout << w+y << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 88
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> w >> x >> y >> z;
#     cout << w+x << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 89
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> z >> x >> y >> z;
#     cout << w+x << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 90
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> w >> x >> y >> z;
#     cout << w+x << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 91
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> y >> x >> y >> z;
#     cout << w+x << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 92
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> x >> x >> y >> z;
#     cout << w+x << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 93
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> w >> x >> z >> z;
#     cout << w+x << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 94
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> w >> x >> w >> z;
#     cout << w+x << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 95
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> w >> x >> y >> z;
#     cout << w+x << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 96
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> w >> x >> x >> z;
#     cout << w+x << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 97
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> w >> x >> y >> z;
#     cout << z+x << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 98
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> w >> x >> y >> z;
#     cout << w+x << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 99
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> w >> x >> y >> z;
#     cout << y+x << endl;
#     return 0;
# }
# ===========================================
# validModificationCount   # 100
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> w >> x >> y >> z;
#     cout << x+x << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 101
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> w >> x >> y >> z;
#     cout << w+x << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 102
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> w >> x >> y >> w;
#     cout << w+x << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 103
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> w >> x >> y >> y;
#     cout << w+x << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 104
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> w >> x >> y >> x;
#     cout << w+x << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 105
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> z >> x >> y >> z;
#     cout << w+z << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 106
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> w >> x >> y >> z;
#     cout << w+z << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 107
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> y >> x >> y >> z;
#     cout << w+z << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 108
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> x >> x >> y >> z;
#     cout << w+z << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 109
# TEST RESULTS:
# [1]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> w >> x >> z >> z;
#     cout << w+z << endl;
#     return 0;
# }
#
# ===========================================
# validModificationCount   # 110
# TEST RESULTS:
# [0, 0]
# MODIFIED SRC:
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> w >> x >> w >> z;
#     cout << w+z << endl;
#     return 0;
# }
#
#
# ====================================== RESULT
# ====================================== RESULT
# ====================================== RESULT
# ====================================== SRC
# #include <iostream>
#
# using namespace std;
#
# int main(void){
#     int w, x, y, z;
#     cin >> w >> x >> w >> z;
#     cout << w+z << endl;
#     return 0;
# }
# ====================================== RS
# 0
# ====================================== Result code for each testcases
# [0, 0]
# ====================================== VSCM Indices
# ====================================== modifiedLineNum
# [7, 6]
# ====================================== ELAPSED TIME
# 43.44595766067505
